# %%
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

##pip show tensorflow

# %%
# Load the dataset
df = pd.read_csv('Alphabets_data.csv')

# Display basic information and the first few rows
df_info = df.info()
df_head = df.head()
df_description = df.describe()
df_nulls = df.isnull().sum()

df_info, df_head, df_description, df_nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB
# (None,
#    letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
#  0      T     2     8      3       5      1     8    13      0      6      6
#  1      I     5    12      3       7      2    10     5      5      4     13
#  2      D     4    11      6       8      6    10     6      2      6     10
#  3      N     7    11      6       6      3     5     9      4      6      4
#  4      G     2     1      3       1      1     8     6      6      6      6
#
#     x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
#  0      10       8      0       8      0       8
#  1       3       9      2       8      4      10
#  2       3       7      3       7      3       9
#  3       4      10      6      10      2       8
#  4       5       9      1       7      5      10  ,
#                 xbox          ybox         width       height         onpix  \
#  count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
#  mean       4.023550      7.035500      5.121850      5.37245      3.505850
#  std        1.913212      3.304555      2.014573      2.26139      2.190458
#  min        0.000000      0.000000      0.000000      0.00000      0.000000
#  25%        3.000000      5.000000      4.000000      4.00000      2.000000
#  50%        4.000000      7.000000      5.000000      6.00000      3.000000
#  75%        5.000000      9.000000      6.000000      7.00000      5.000000
#  max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                 xbar          ybar         x2bar         y2bar         xybar  \
#  count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
#  mean       6.897600      7.500450      4.628600      5.178650      8.282050
#  std        2.026035      2.325354      2.699968      2.380823      2.488475
#  min        0.000000      0.000000      0.000000      0.000000      0.000000
#  25%        6.000000      6.000000      3.000000      4.000000      7.000000
#  50%        7.000000      7.000000      4.000000      5.000000      8.000000
#  75%        8.000000      9.000000      6.000000      7.000000     10.000000
#  max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#              x2ybar        xy2bar         xedge        xedgey         yedge  \
#  count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
#  mean       6.45400      7.929000      3.046100      8.338850      3.691750
#  std        2.63107      2.080619      2.332541      1.546722      2.567073
#  min        0.00000      0.000000      0.000000      0.000000      0.000000
#  25%        5.00000      7.000000      1.000000      8.000000      2.000000
#  50%        6.00000      8.000000      3.000000      8.000000      3.000000
#  75%        8.00000      9.000000      4.000000      9.000000      5.000000
#  max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#              yedgex
#  count  20000.00000
#  mean       7.80120
#  std        1.61747
#  min        0.00000
#  25%        7.00000
#  50%        8.00000
#  75%        9.00000
#  max       15.00000  ,
#  letter    0
#  xbox      0
#  ybox      0
#  width     0
#  height    0
#  onpix     0
#  xbar      0
#  ybar      0
#  x2bar     0
#  y2bar     0
#  xybar     0
#  x2ybar    0
#  xy2bar    0
#  xedge     0
#  xedgey    0
#  yedge     0
#  yedgex    0
#  dtype: int64)

# %%
# Separate features and target
X = df.drop('letter', axis=1)
y = df['letter']

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Normalize the feature data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into train and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

X_train.shape, X_test.shape, y_train.shape, y_test.shape

# Train MLP Classifier
mlp = MLPClassifier(hidden_layer_sizes=(64,), activation='relu', solver='adam', max_iter=300, random_state=42)
mlp.fit(X_train, y_train)

# Evaluate
y_pred = mlp.predict(X_test)
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.99      0.97      0.98       158
#            B       0.90      0.92      0.91       153
#            C       0.93      0.97      0.95       147
#            D       0.94      0.96      0.95       161
#            E       0.93      0.96      0.94       154
#            F       0.94      0.92      0.93       155
#            G       0.95      0.95      0.95       155
#            H       0.90      0.84      0.87       147
#            I       0.98      0.91      0.95       151
#            J       0.91      0.96      0.93       149
#            K       0.90      0.93      0.91       148
#            L       0.97      0.95      0.96       152
#            M       0.97      0.94      0.96       158
#            N       0.95      0.90      0.93       157
#            O       0.94      0.92      0.93       150
#            P       0.96      0.96      0.96       161
#            Q       0.96      0.97      0.97       157
#            R       0.90      0.91      0.90       151
#            S       0.91      0.95      0.93       150
#            T       0.96      0.97      0.97       159
#            U       0.96      1.00      0.98       163
#            V       0.96      0.96      0.96       153
#            W       0.96      0.99      0.98       150
#            X       0.94      0.92      0.93       157
#            Y       0.97      0.97      0.97       157
#            Z       0.98      0.96      0.97       147
#
#     accuracy                           0.94      4000
#    macro avg       0.94      0.94      0.94      4000
# weighted avg       0.95      0.94      0.94      4000

# %%
model = Sequential()
model.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(26, activation='softmax'))  # Assuming 26 classes (A-Z)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2724 - loss: 2.6426 - val_accuracy: 0.6513 - val_loss: 1.3945
# Epoch 2/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6745 - loss: 1.2642 - val_accuracy: 0.7469 - val_loss: 0.9861
# Epoch 3/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7503 - loss: 0.9392 - val_accuracy: 0.7844 - val_loss: 0.8236
# Epoch 4/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7867 - loss: 0.7836 - val_accuracy: 0.8044 - val_loss: 0.7296
# Epoch 5/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8017 - loss: 0.6941 - val_accuracy: 0.8213 - val_loss: 0.6606
# Epoch 6/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8249 - loss: 0.6245 - val_accuracy: 0.8359 - val_loss: 0.6106
# Epoch 7/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8353 - loss: 0.5770 - val_accuracy: 0.8438 - val_loss: 0.5673
# Epoch 8/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8582 - loss: 0.5132 - val_accuracy: 0.8487 - val_loss: 0.5331
# Epoch 9/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8662 - loss: 0.4784 - val_accuracy: 0.8622 - val_loss: 0.5048
# Epoch 10/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8694 - loss: 0.4638 - val_accuracy: 0.8622 - val_loss: 0.4825
# Epoch 11/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8751 - loss: 0.4405 - val_accuracy: 0.8675 - val_loss: 0.4605
# Epoch 12/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8804 - loss: 0.4202 - val_accuracy: 0.8700 - val_loss: 0.4396
# Epoch 13/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8913 - loss: 0.3857 - val_accuracy: 0.8719 - val_loss: 0.4239
# Epoch 14/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8957 - loss: 0.3741 - val_accuracy: 0.8766 - val_loss: 0.4115
# Epoch 15/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8989 - loss: 0.3586 - val_accuracy: 0.8788 - val_loss: 0.3958
# Epoch 16/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9080 - loss: 0.3333 - val_accuracy: 0.8825 - val_loss: 0.3833
# Epoch 17/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9112 - loss: 0.3162 - val_accuracy: 0.8869 - val_loss: 0.3722
# Epoch 18/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9065 - loss: 0.3156 - val_accuracy: 0.8881 - val_loss: 0.3607
# Epoch 19/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9122 - loss: 0.3059 - val_accuracy: 0.8928 - val_loss: 0.3549
# Epoch 20/20
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9185 - loss: 0.2868 - val_accuracy: 0.8928 - val_loss: 0.3455
